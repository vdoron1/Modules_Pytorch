# %%
# %run homework_modules.ipynb
# Out:
# X shape: (20, 3)
# y shape: (20, 3)
# feature names: ['Chins', 'Situps', 'Jumps']
# target names: ['Weight', 'Waist', 'Pulse']
# train: (12, 3) (12, 3)
# val: (4, 3) (4, 3)
# test: (4, 3) (4, 3)
# Epoch 001 | lr=0.000200 | train_loss=0.866286 | val_loss=1.199041 | train_metric=9.487985 | val_metric=7.354002
# Epoch 002 | lr=0.000400 | train_loss=1.152767 | val_loss=1.197836 | train_metric=9.491204 | val_metric=7.325754
# Epoch 003 | lr=0.000600 | train_loss=1.190081 | val_loss=1.196921 | train_metric=9.488895 | val_metric=7.283172
# Epoch 004 | lr=0.000800 | train_loss=0.848811 | val_loss=1.195687 | train_metric=9.485804 | val_metric=7.206223
# Epoch 005 | lr=0.001000 | train_loss=0.943416 | val_loss=1.194998 | train_metric=9.479567 | val_metric=7.132737
# Epoch 006 | lr=0.001000 | train_loss=0.854153 | val_loss=1.194265 | train_metric=9.475489 | val_metric=7.049997
# Epoch 007 | lr=0.001000 | train_loss=1.187578 | val_loss=1.194664 | train_metric=9.463655 | val_metric=6.991510
# Epoch 008 | lr=0.001000 | train_loss=0.959531 | val_loss=1.193386 | train_metric=9.459528 | val_metric=6.924499
# Epoch 009 | lr=0.001000 | train_loss=0.934938 | val_loss=1.191956 | train_metric=9.458470 | val_metric=6.862275
# Epoch 010 | lr=0.001000 | train_loss=0.884640 | val_loss=1.191507 | train_metric=9.453626 | val_metric=6.785496
# Epoch 011 | lr=0.001000 | train_loss=0.889529 | val_loss=1.190385 | train_metric=9.454518 | val_metric=6.719160
# Epoch 012 | lr=0.001000 | train_loss=1.195961 | val_loss=1.188387 | train_metric=9.457662 | val_metric=6.678205
# Epoch 013 | lr=0.001000 | train_loss=0.830500 | val_loss=1.187118 | train_metric=9.457736 | val_metric=6.607143
# Epoch 014 | lr=0.001000 | train_loss=0.836449 | val_loss=1.186311 | train_metric=9.455925 | val_metric=6.529206
# Epoch 015 | lr=0.001000 | train_loss=1.118111 | val_loss=1.185982 | train_metric=9.450180 | val_metric=6.478942
# Epoch 016 | lr=0.001000 | train_loss=0.855685 | val_loss=1.185359 | train_metric=9.445090 | val_metric=6.412370
# Epoch 017 | lr=0.001000 | train_loss=1.192634 | val_loss=1.184023 | train_metric=9.437498 | val_metric=6.365776
# Epoch 018 | lr=0.001000 | train_loss=0.798274 | val_loss=1.183987 | train_metric=9.431791 | val_metric=6.289280
# Epoch 019 | lr=0.001000 | train_loss=0.983218 | val_loss=1.183648 | train_metric=9.419637 | val_metric=6.229528
# Epoch 020 | lr=0.001000 | train_loss=0.939650 | val_loss=1.184507 | train_metric=9.408738 | val_metric=6.182678
# Epoch 021 | lr=0.001000 | train_loss=1.162830 | val_loss=1.183354 | train_metric=9.407913 | val_metric=6.160945
# Epoch 022 | lr=0.001000 | train_loss=0.798302 | val_loss=1.183178 | train_metric=9.405399 | val_metric=6.104525
# Epoch 023 | lr=0.001000 | train_loss=1.063077 | val_loss=1.182105 | train_metric=9.408264 | val_metric=6.063774
# Epoch 024 | lr=0.001000 | train_loss=0.789377 | val_loss=1.184463 | train_metric=9.399113 | val_metric=5.949399
# Epoch 025 | lr=0.001000 | train_loss=0.775008 | val_loss=1.183812 | train_metric=9.396668 | val_metric=5.902083
# Epoch 026 | lr=0.001000 | train_loss=0.771112 | val_loss=1.184884 | train_metric=9.380588 | val_metric=5.886324
# Epoch 027 | lr=0.001000 | train_loss=0.951571 | val_loss=1.184922 | train_metric=9.368084 | val_metric=5.888707
# Epoch 028 | lr=0.001000 | train_loss=0.787842 | val_loss=1.185602 | train_metric=9.359111 | val_metric=5.878967
# Epoch 029 | lr=0.001000 | train_loss=0.864641 | val_loss=1.186501 | train_metric=9.343969 | val_metric=5.877423
# Epoch 030 | lr=0.001000 | train_loss=1.118711 | val_loss=1.185460 | train_metric=9.345132 | val_metric=5.869607
# Epoch 031 | lr=0.001000 | train_loss=0.839914 | val_loss=1.185729 | train_metric=9.330595 | val_metric=5.869096
# Epoch 032 | lr=0.001000 | train_loss=0.799070 | val_loss=1.186596 | train_metric=9.317756 | val_metric=5.855739
# Epoch 033 | lr=0.000500 | train_loss=0.798072 | val_loss=1.187340 | train_metric=9.303865 | val_metric=5.847366
# Epoch 034 | lr=0.000500 | train_loss=0.818150 | val_loss=1.188824 | train_metric=9.296329 | val_metric=5.833958
# Epoch 035 | lr=0.000500 | train_loss=0.850835 | val_loss=1.189324 | train_metric=9.292161 | val_metric=5.820830
# Epoch 036 | lr=0.000500 | train_loss=1.058659 | val_loss=1.187059 | train_metric=9.294703 | val_metric=5.817598
# Epoch 037 | lr=0.000500 | train_loss=0.871094 | val_loss=1.186478 | train_metric=9.293352 | val_metric=5.808126
# Epoch 038 | lr=0.000500 | train_loss=1.048402 | val_loss=1.186348 | train_metric=9.282412 | val_metric=5.810619
# Epoch 039 | lr=0.000500 | train_loss=0.848516 | val_loss=1.186572 | train_metric=9.279977 | val_metric=5.796341
# Epoch 040 | lr=0.000500 | train_loss=1.052307 | val_loss=1.187281 | train_metric=9.282510 | val_metric=5.780016
# Epoch 041 | lr=0.000500 | train_loss=0.828143 | val_loss=1.187751 | train_metric=9.266131 | val_metric=5.782727
# Epoch 042 | lr=0.000500 | train_loss=0.870839 | val_loss=1.188849 | train_metric=9.258102 | val_metric=5.773844
# Epoch 043 | lr=0.000250 | train_loss=0.795599 | val_loss=1.189517 | train_metric=9.247862 | val_metric=5.779654
# Early stopping at epoch 43
# Epoch 001 | lr=0.000200 | train_loss=1.028726 | val_loss=1.094095 | train_metric=11.181963 | val_metric=5.111165
# Epoch 002 | lr=0.000400 | train_loss=1.013368 | val_loss=1.093363 | train_metric=11.184481 | val_metric=5.112458
# Epoch 003 | lr=0.000600 | train_loss=0.925856 | val_loss=1.092018 | train_metric=11.188778 | val_metric=5.111359
# Epoch 004 | lr=0.000800 | train_loss=1.057000 | val_loss=1.091970 | train_metric=11.180866 | val_metric=5.115663
# Epoch 005 | lr=0.001000 | train_loss=0.986226 | val_loss=1.096093 | train_metric=11.142655 | val_metric=5.123353
# Epoch 006 | lr=0.001000 | train_loss=0.906331 | val_loss=1.098929 | train_metric=11.111227 | val_metric=5.128231
# Epoch 007 | lr=0.001000 | train_loss=1.018036 | val_loss=1.103139 | train_metric=11.075894 | val_metric=5.131635
# Epoch 008 | lr=0.001000 | train_loss=1.118763 | val_loss=1.105961 | train_metric=11.048679 | val_metric=5.124340
# Epoch 009 | lr=0.001000 | train_loss=1.150389 | val_loss=1.108492 | train_metric=11.028901 | val_metric=5.116941
# Epoch 010 | lr=0.001000 | train_loss=0.870465 | val_loss=1.110023 | train_metric=11.016017 | val_metric=5.121638
# Epoch 011 | lr=0.001000 | train_loss=1.138469 | val_loss=1.111863 | train_metric=11.002859 | val_metric=5.115688
# Epoch 012 | lr=0.001000 | train_loss=1.257212 | val_loss=1.115752 | train_metric=10.972597 | val_metric=5.124535
# Epoch 013 | lr=0.001000 | train_loss=1.037063 | val_loss=1.117748 | train_metric=10.955119 | val_metric=5.129740
# Epoch 014 | lr=0.000500 | train_loss=0.995364 | val_loss=1.118934 | train_metric=10.935909 | val_metric=5.116414
# Epoch 015 | lr=0.000500 | train_loss=0.977494 | val_loss=1.119294 | train_metric=10.933959 | val_metric=5.114330
# Epoch 016 | lr=0.000500 | train_loss=1.163796 | val_loss=1.119067 | train_metric=10.926149 | val_metric=5.115642
# Epoch 017 | lr=0.000500 | train_loss=1.146886 | val_loss=1.119848 | train_metric=10.909279 | val_metric=5.107052
# Epoch 018 | lr=0.000500 | train_loss=0.930418 | val_loss=1.120016 | train_metric=10.906779 | val_metric=5.115121
# Epoch 019 | lr=0.000500 | train_loss=1.015117 | val_loss=1.120393 | train_metric=10.899968 | val_metric=5.109175
# Epoch 020 | lr=0.000500 | train_loss=1.141281 | val_loss=1.119114 | train_metric=10.888408 | val_metric=5.106714
# Epoch 021 | lr=0.000500 | train_loss=0.993266 | val_loss=1.118701 | train_metric=10.888818 | val_metric=5.101987
# Epoch 022 | lr=0.000500 | train_loss=0.993116 | val_loss=1.118412 | train_metric=10.885864 | val_metric=5.102479
# Epoch 023 | lr=0.000500 | train_loss=0.952675 | val_loss=1.120751 | train_metric=10.885256 | val_metric=5.109027
# Epoch 024 | lr=0.000250 | train_loss=1.156615 | val_loss=1.120840 | train_metric=10.877862 | val_metric=5.103930
# Early stopping at epoch 24
# Epoch 001 | lr=0.000200 | train_loss=0.967798 | val_loss=1.041790 | train_metric=11.053613 | val_metric=5.217124
# Epoch 002 | lr=0.000400 | train_loss=1.271537 | val_loss=1.039667 | train_metric=11.040386 | val_metric=5.196279
# Epoch 003 | lr=0.000600 | train_loss=1.236080 | val_loss=1.040133 | train_metric=11.035757 | val_metric=5.193658
# Epoch 004 | lr=0.000800 | train_loss=0.850634 | val_loss=1.040785 | train_metric=11.008632 | val_metric=5.156947
# Epoch 005 | lr=0.001000 | train_loss=0.856487 | val_loss=1.039260 | train_metric=10.979984 | val_metric=5.120613
# Epoch 006 | lr=0.001000 | train_loss=0.947602 | val_loss=1.038257 | train_metric=10.948282 | val_metric=5.081806
# Epoch 007 | lr=0.001000 | train_loss=0.944910 | val_loss=1.036404 | train_metric=10.922862 | val_metric=5.070221
# Epoch 008 | lr=0.001000 | train_loss=0.940646 | val_loss=1.035255 | train_metric=10.895379 | val_metric=5.034588
# Epoch 009 | lr=0.001000 | train_loss=0.926429 | val_loss=1.037603 | train_metric=10.855223 | val_metric=5.014764
# Epoch 010 | lr=0.001000 | train_loss=1.005043 | val_loss=1.039993 | train_metric=10.829675 | val_metric=5.007205
# Epoch 011 | lr=0.001000 | train_loss=1.289363 | val_loss=1.039862 | train_metric=10.798284 | val_metric=4.990877
# Epoch 012 | lr=0.001000 | train_loss=1.056870 | val_loss=1.042830 | train_metric=10.778982 | val_metric=4.977001
# Epoch 013 | lr=0.001000 | train_loss=0.979377 | val_loss=1.045943 | train_metric=10.749430 | val_metric=4.956805
# Epoch 014 | lr=0.001000 | train_loss=1.167592 | val_loss=1.044904 | train_metric=10.726158 | val_metric=4.932786
# Epoch 015 | lr=0.001000 | train_loss=0.867501 | val_loss=1.047151 | train_metric=10.707058 | val_metric=4.920231
# Epoch 016 | lr=0.001000 | train_loss=0.953051 | val_loss=1.049479 | train_metric=10.683114 | val_metric=4.903088
# Epoch 017 | lr=0.001000 | train_loss=1.161990 | val_loss=1.050116 | train_metric=10.681792 | val_metric=4.911239
# Epoch 018 | lr=0.000500 | train_loss=1.208780 | val_loss=1.054039 | train_metric=10.667359 | val_metric=4.910962
# Epoch 019 | lr=0.000500 | train_loss=1.199842 | val_loss=1.052249 | train_metric=10.647482 | val_metric=4.886170
# Epoch 020 | lr=0.000500 | train_loss=0.886765 | val_loss=1.053797 | train_metric=10.633295 | val_metric=4.877181
# Epoch 021 | lr=0.000500 | train_loss=1.245202 | val_loss=1.054583 | train_metric=10.617466 | val_metric=4.868063
# Epoch 022 | lr=0.000500 | train_loss=1.193865 | val_loss=1.050903 | train_metric=10.620790 | val_metric=4.849087
# Epoch 023 | lr=0.000500 | train_loss=0.880370 | val_loss=1.049973 | train_metric=10.618149 | val_metric=4.848369
# Epoch 024 | lr=0.000500 | train_loss=1.103405 | val_loss=1.051803 | train_metric=10.602391 | val_metric=4.842406
# Epoch 025 | lr=0.000500 | train_loss=0.992415 | val_loss=1.052001 | train_metric=10.608068 | val_metric=4.845845
# Epoch 026 | lr=0.000500 | train_loss=0.957307 | val_loss=1.051446 | train_metric=10.599701 | val_metric=4.837432
# Epoch 027 | lr=0.000500 | train_loss=1.254605 | val_loss=1.052512 | train_metric=10.586232 | val_metric=4.827525
# Epoch 028 | lr=0.000250 | train_loss=0.837892 | val_loss=1.050804 | train_metric=10.582895 | val_metric=4.816837
# Early stopping at epoch 28
# Small FCNN:
#   test_loss (scaled MSE) = 0.522857
#   test_MAE = 8.933508
#   test_R2 = -0.580282
# Medium FCNN:
#   test_loss (scaled MSE) = 0.513617
#   test_MAE = 7.349732
#   test_R2 = -0.037785
# Large FCNN:
#   test_loss (scaled MSE) = 0.499146
#   test_MAE = 7.378914
#   test_R2 = -0.024926
# {'name': 'Small FCNN', 'test_loss': np.float64(0.5228565038040076), 'test_mae': np.float64(8.933507528085414), 'test_r2': np.float64(-0.5802817892645635)}
# {'name': 'Medium FCNN', 'test_loss': np.float64(0.513617312302363), 'test_mae': np.float64(7.349731866922926), 'test_r2': np.float64(-0.03778531753496317)}
# {'name': 'Large FCNN', 'test_loss': np.float64(0.49914612195045693), 'test_mae': np.float64(7.3789135359054), 'test_r2': np.float64(-0.02492626668540221)}
#
# Training medium model with activation = relu
# Epoch 001 | lr=0.000200 | train_loss=0.873921 | val_loss=1.186306 | train_metric=9.474113 | val_metric=7.857563
# Epoch 002 | lr=0.000400 | train_loss=1.189396 | val_loss=1.184437 | train_metric=9.473465 | val_metric=7.850403
# Epoch 003 | lr=0.000600 | train_loss=0.929240 | val_loss=1.185257 | train_metric=9.480015 | val_metric=7.822114
# Epoch 004 | lr=0.000800 | train_loss=0.882970 | val_loss=1.185345 | train_metric=9.484146 | val_metric=7.775193
# Epoch 005 | lr=0.001000 | train_loss=1.164843 | val_loss=1.184103 | train_metric=9.493442 | val_metric=7.723832
# Epoch 006 | lr=0.001000 | train_loss=0.928773 | val_loss=1.182123 | train_metric=9.499831 | val_metric=7.667547
# Epoch 007 | lr=0.001000 | train_loss=1.187025 | val_loss=1.182052 | train_metric=9.495347 | val_metric=7.643085
# Epoch 008 | lr=0.001000 | train_loss=0.887276 | val_loss=1.179045 | train_metric=9.502952 | val_metric=7.585566
# Epoch 009 | lr=0.001000 | train_loss=1.180656 | val_loss=1.178315 | train_metric=9.492914 | val_metric=7.561971
# Epoch 010 | lr=0.001000 | train_loss=1.205318 | val_loss=1.177168 | train_metric=9.489847 | val_metric=7.520194
# Epoch 011 | lr=0.001000 | train_loss=0.873132 | val_loss=1.179580 | train_metric=9.492998 | val_metric=7.521909
# Epoch 012 | lr=0.001000 | train_loss=1.244879 | val_loss=1.177261 | train_metric=9.491342 | val_metric=7.476109
# Epoch 013 | lr=0.001000 | train_loss=0.866096 | val_loss=1.176606 | train_metric=9.493421 | val_metric=7.451640
# Epoch 014 | lr=0.001000 | train_loss=0.856791 | val_loss=1.177127 | train_metric=9.494759 | val_metric=7.449089
# Epoch 015 | lr=0.001000 | train_loss=0.889820 | val_loss=1.176191 | train_metric=9.485938 | val_metric=7.425605
# Epoch 016 | lr=0.001000 | train_loss=1.170653 | val_loss=1.173171 | train_metric=9.493568 | val_metric=7.363544
# Epoch 017 | lr=0.001000 | train_loss=0.851088 | val_loss=1.175039 | train_metric=9.489943 | val_metric=7.371186
# Epoch 018 | lr=0.001000 | train_loss=0.886563 | val_loss=1.176197 | train_metric=9.477865 | val_metric=7.369037
# Epoch 019 | lr=0.001000 | train_loss=1.146273 | val_loss=1.174101 | train_metric=9.478680 | val_metric=7.335686
# Epoch 020 | lr=0.001000 | train_loss=0.828897 | val_loss=1.174053 | train_metric=9.463666 | val_metric=7.312956
# Epoch 021 | lr=0.001000 | train_loss=0.896441 | val_loss=1.174994 | train_metric=9.465241 | val_metric=7.288978
# Epoch 022 | lr=0.001000 | train_loss=0.818603 | val_loss=1.176274 | train_metric=9.461578 | val_metric=7.299412
# Epoch 023 | lr=0.001000 | train_loss=0.804874 | val_loss=1.177963 | train_metric=9.444779 | val_metric=7.307266
# Epoch 024 | lr=0.001000 | train_loss=0.888171 | val_loss=1.181521 | train_metric=9.450661 | val_metric=7.341649
# Epoch 025 | lr=0.001000 | train_loss=0.854571 | val_loss=1.181817 | train_metric=9.437254 | val_metric=7.338093
# Epoch 026 | lr=0.000500 | train_loss=0.813608 | val_loss=1.178912 | train_metric=9.431571 | val_metric=7.302588
# Epoch 027 | lr=0.000500 | train_loss=0.828359 | val_loss=1.177996 | train_metric=9.437116 | val_metric=7.290359
# Epoch 028 | lr=0.000500 | train_loss=1.264178 | val_loss=1.177998 | train_metric=9.408798 | val_metric=7.296511
# Epoch 029 | lr=0.000500 | train_loss=0.894288 | val_loss=1.176653 | train_metric=9.425933 | val_metric=7.268514
# Epoch 030 | lr=0.000500 | train_loss=0.928516 | val_loss=1.176314 | train_metric=9.429941 | val_metric=7.256967
# Epoch 031 | lr=0.000500 | train_loss=1.198704 | val_loss=1.176926 | train_metric=9.435679 | val_metric=7.231496
# Epoch 032 | lr=0.000500 | train_loss=1.211404 | val_loss=1.175622 | train_metric=9.432970 | val_metric=7.208494
# Epoch 033 | lr=0.000500 | train_loss=1.140980 | val_loss=1.173465 | train_metric=9.422591 | val_metric=7.178275
# Epoch 034 | lr=0.000500 | train_loss=1.084868 | val_loss=1.173531 | train_metric=9.450994 | val_metric=7.136948
# Epoch 035 | lr=0.000500 | train_loss=1.117502 | val_loss=1.174338 | train_metric=9.435022 | val_metric=7.139107
# Epoch 036 | lr=0.000250 | train_loss=0.820956 | val_loss=1.176485 | train_metric=9.441387 | val_metric=7.151406
# Early stopping at epoch 36
# Medium FCNN (relu):
#   test_loss (scaled MSE) = 0.563889
#   test_MAE = 9.522695
#   test_R2 = -0.851457
#
# Training medium model with activation = elu
# Epoch 001 | lr=0.000200 | train_loss=1.153727 | val_loss=1.096706 | train_metric=10.317471 | val_metric=4.825763
# Epoch 002 | lr=0.000400 | train_loss=0.920884 | val_loss=1.091369 | train_metric=10.272520 | val_metric=4.828880
# Epoch 003 | lr=0.000600 | train_loss=0.810343 | val_loss=1.084295 | train_metric=10.246555 | val_metric=4.782113
# Epoch 004 | lr=0.000800 | train_loss=0.938570 | val_loss=1.081237 | train_metric=10.188430 | val_metric=4.817595
# Epoch 005 | lr=0.001000 | train_loss=0.793848 | val_loss=1.080036 | train_metric=10.154055 | val_metric=4.815160
# Epoch 006 | lr=0.001000 | train_loss=0.885132 | val_loss=1.076664 | train_metric=10.140007 | val_metric=4.772093
# Epoch 007 | lr=0.001000 | train_loss=0.900396 | val_loss=1.071070 | train_metric=10.077700 | val_metric=4.775383
# Epoch 008 | lr=0.001000 | train_loss=1.009589 | val_loss=1.067739 | train_metric=10.030480 | val_metric=4.781620
# Epoch 009 | lr=0.001000 | train_loss=1.094409 | val_loss=1.070805 | train_metric=10.011598 | val_metric=4.778775
# Epoch 010 | lr=0.001000 | train_loss=0.871959 | val_loss=1.064746 | train_metric=9.956930 | val_metric=4.777340
# Epoch 011 | lr=0.001000 | train_loss=1.156614 | val_loss=1.064262 | train_metric=9.908333 | val_metric=4.797970
# Epoch 012 | lr=0.001000 | train_loss=0.917431 | val_loss=1.056377 | train_metric=9.827221 | val_metric=4.811893
# Epoch 013 | lr=0.001000 | train_loss=0.804740 | val_loss=1.053863 | train_metric=9.805670 | val_metric=4.795111
# Epoch 014 | lr=0.001000 | train_loss=0.846174 | val_loss=1.053132 | train_metric=9.783844 | val_metric=4.800111
# Epoch 015 | lr=0.001000 | train_loss=0.848755 | val_loss=1.048141 | train_metric=9.744004 | val_metric=4.803088
# Epoch 016 | lr=0.001000 | train_loss=1.066175 | val_loss=1.045236 | train_metric=9.673939 | val_metric=4.848955
# Epoch 017 | lr=0.001000 | train_loss=0.887978 | val_loss=1.044002 | train_metric=9.662000 | val_metric=4.859606
# Epoch 018 | lr=0.001000 | train_loss=1.107345 | val_loss=1.042398 | train_metric=9.609666 | val_metric=4.894536
# Epoch 019 | lr=0.001000 | train_loss=0.846539 | val_loss=1.042195 | train_metric=9.595823 | val_metric=4.887615
# Epoch 020 | lr=0.001000 | train_loss=0.945282 | val_loss=1.039853 | train_metric=9.528165 | val_metric=4.910353
# Epoch 021 | lr=0.001000 | train_loss=1.122833 | val_loss=1.041842 | train_metric=9.457908 | val_metric=4.991972
# Epoch 022 | lr=0.001000 | train_loss=0.778468 | val_loss=1.040778 | train_metric=9.474870 | val_metric=4.967028
# Epoch 023 | lr=0.001000 | train_loss=0.780767 | val_loss=1.040912 | train_metric=9.438568 | val_metric=4.992547
# Epoch 024 | lr=0.001000 | train_loss=0.841271 | val_loss=1.045150 | train_metric=9.444233 | val_metric=4.997608
# Epoch 025 | lr=0.001000 | train_loss=0.880421 | val_loss=1.042668 | train_metric=9.436655 | val_metric=4.975910
# Epoch 026 | lr=0.001000 | train_loss=0.899533 | val_loss=1.041815 | train_metric=9.421517 | val_metric=4.991375
# Epoch 027 | lr=0.001000 | train_loss=0.954930 | val_loss=1.043131 | train_metric=9.414461 | val_metric=5.019708
# Epoch 028 | lr=0.001000 | train_loss=0.986470 | val_loss=1.047652 | train_metric=9.367410 | val_metric=5.079408
# Epoch 029 | lr=0.001000 | train_loss=0.719363 | val_loss=1.045032 | train_metric=9.337793 | val_metric=5.084122
# Epoch 030 | lr=0.000500 | train_loss=0.826757 | val_loss=1.043198 | train_metric=9.292031 | val_metric=5.111008
# Epoch 031 | lr=0.000500 | train_loss=0.720030 | val_loss=1.049721 | train_metric=9.315713 | val_metric=5.111546
# Epoch 032 | lr=0.000500 | train_loss=0.686076 | val_loss=1.051791 | train_metric=9.291103 | val_metric=5.111233
# Epoch 033 | lr=0.000500 | train_loss=0.766549 | val_loss=1.051630 | train_metric=9.220638 | val_metric=5.157483
# Epoch 034 | lr=0.000500 | train_loss=0.955010 | val_loss=1.051102 | train_metric=9.250064 | val_metric=5.119462
# Epoch 035 | lr=0.000500 | train_loss=0.729761 | val_loss=1.053521 | train_metric=9.234620 | val_metric=5.124219
# Epoch 036 | lr=0.000500 | train_loss=0.775594 | val_loss=1.056277 | train_metric=9.224549 | val_metric=5.127325
# Epoch 037 | lr=0.000500 | train_loss=0.683983 | val_loss=1.058012 | train_metric=9.261515 | val_metric=5.082244
# Epoch 038 | lr=0.000500 | train_loss=1.024232 | val_loss=1.053199 | train_metric=9.215117 | val_metric=5.104274
# Epoch 039 | lr=0.000500 | train_loss=0.746931 | val_loss=1.051021 | train_metric=9.197823 | val_metric=5.094658
# Epoch 040 | lr=0.000250 | train_loss=0.731640 | val_loss=1.053167 | train_metric=9.188063 | val_metric=5.073218
# Early stopping at epoch 40
# Medium FCNN (elu):
#   test_loss (scaled MSE) = 0.483157
#   test_MAE = 7.958628
#   test_R2 = -0.189307
#
# Training medium model with activation = gelu
# Epoch 001 | lr=0.000200 | train_loss=1.157985 | val_loss=1.149747 | train_metric=10.462438 | val_metric=4.985687
# Epoch 002 | lr=0.000400 | train_loss=0.896297 | val_loss=1.147353 | train_metric=10.460941 | val_metric=4.965156
# Epoch 003 | lr=0.000600 | train_loss=0.903108 | val_loss=1.143548 | train_metric=10.447174 | val_metric=4.954607
# Epoch 004 | lr=0.000800 | train_loss=0.910810 | val_loss=1.140460 | train_metric=10.432195 | val_metric=4.946047
# Epoch 005 | lr=0.001000 | train_loss=0.909215 | val_loss=1.135892 | train_metric=10.401567 | val_metric=4.947141
# Epoch 006 | lr=0.001000 | train_loss=0.873345 | val_loss=1.133387 | train_metric=10.376742 | val_metric=4.946921
# Epoch 007 | lr=0.001000 | train_loss=1.007106 | val_loss=1.130535 | train_metric=10.357496 | val_metric=4.939680
# Epoch 008 | lr=0.001000 | train_loss=1.184074 | val_loss=1.129503 | train_metric=10.325852 | val_metric=4.955765
# Epoch 009 | lr=0.001000 | train_loss=0.872155 | val_loss=1.127919 | train_metric=10.314043 | val_metric=4.947242
# Epoch 010 | lr=0.001000 | train_loss=1.017259 | val_loss=1.126790 | train_metric=10.297846 | val_metric=4.941846
# Epoch 011 | lr=0.001000 | train_loss=0.887281 | val_loss=1.125124 | train_metric=10.276597 | val_metric=4.941116
# Epoch 012 | lr=0.001000 | train_loss=1.171863 | val_loss=1.124836 | train_metric=10.259862 | val_metric=4.943306
# Epoch 013 | lr=0.001000 | train_loss=0.879308 | val_loss=1.123606 | train_metric=10.240675 | val_metric=4.940505
# Epoch 014 | lr=0.001000 | train_loss=1.098432 | val_loss=1.121886 | train_metric=10.214338 | val_metric=4.940119
# Epoch 015 | lr=0.001000 | train_loss=0.850060 | val_loss=1.119525 | train_metric=10.191629 | val_metric=4.934857
# Epoch 016 | lr=0.001000 | train_loss=1.002381 | val_loss=1.117200 | train_metric=10.166182 | val_metric=4.928050
# Epoch 017 | lr=0.001000 | train_loss=1.090725 | val_loss=1.118996 | train_metric=10.167904 | val_metric=4.917823
# Epoch 018 | lr=0.001000 | train_loss=0.887012 | val_loss=1.117394 | train_metric=10.152215 | val_metric=4.906090
# Epoch 019 | lr=0.001000 | train_loss=0.976247 | val_loss=1.117394 | train_metric=10.143259 | val_metric=4.894719
# Epoch 020 | lr=0.001000 | train_loss=0.873315 | val_loss=1.115960 | train_metric=10.118504 | val_metric=4.900938
# Epoch 021 | lr=0.001000 | train_loss=0.858726 | val_loss=1.114742 | train_metric=10.091808 | val_metric=4.890972
# Epoch 022 | lr=0.001000 | train_loss=1.078687 | val_loss=1.115742 | train_metric=10.060451 | val_metric=4.906190
# Epoch 023 | lr=0.001000 | train_loss=0.945679 | val_loss=1.114017 | train_metric=10.035896 | val_metric=4.903687
# Epoch 024 | lr=0.001000 | train_loss=0.968325 | val_loss=1.111931 | train_metric=9.992813 | val_metric=4.919440
# Epoch 025 | lr=0.001000 | train_loss=0.873338 | val_loss=1.111530 | train_metric=9.977392 | val_metric=4.913626
# Epoch 026 | lr=0.001000 | train_loss=0.968276 | val_loss=1.111555 | train_metric=9.972151 | val_metric=4.896344
# Epoch 027 | lr=0.001000 | train_loss=0.805973 | val_loss=1.109895 | train_metric=9.909468 | val_metric=4.926993
# Epoch 028 | lr=0.001000 | train_loss=0.940555 | val_loss=1.110310 | train_metric=9.890048 | val_metric=4.940756
# Epoch 029 | lr=0.001000 | train_loss=0.947768 | val_loss=1.110644 | train_metric=9.892544 | val_metric=4.929790
# Epoch 030 | lr=0.001000 | train_loss=0.849560 | val_loss=1.110408 | train_metric=9.884646 | val_metric=4.919907
# Epoch 031 | lr=0.001000 | train_loss=0.912916 | val_loss=1.111306 | train_metric=9.880880 | val_metric=4.925285
# Epoch 032 | lr=0.001000 | train_loss=1.130313 | val_loss=1.111759 | train_metric=9.868615 | val_metric=4.936459
# Epoch 033 | lr=0.001000 | train_loss=1.087620 | val_loss=1.111490 | train_metric=9.847300 | val_metric=4.948063
# Epoch 034 | lr=0.001000 | train_loss=0.803694 | val_loss=1.110326 | train_metric=9.827160 | val_metric=4.939612
# Epoch 035 | lr=0.001000 | train_loss=1.022248 | val_loss=1.107604 | train_metric=9.773457 | val_metric=4.955640
# Epoch 036 | lr=0.001000 | train_loss=0.830504 | val_loss=1.107590 | train_metric=9.750938 | val_metric=4.959560
# Epoch 037 | lr=0.001000 | train_loss=0.886108 | val_loss=1.106556 | train_metric=9.751720 | val_metric=4.951421
# Epoch 038 | lr=0.001000 | train_loss=1.165675 | val_loss=1.104620 | train_metric=9.697371 | val_metric=4.976316
# Epoch 039 | lr=0.001000 | train_loss=0.832166 | val_loss=1.103835 | train_metric=9.673668 | val_metric=4.977050
# Epoch 040 | lr=0.001000 | train_loss=0.936607 | val_loss=1.103684 | train_metric=9.668950 | val_metric=4.969367
# Epoch 041 | lr=0.001000 | train_loss=0.837784 | val_loss=1.102657 | train_metric=9.638167 | val_metric=4.980224
# Epoch 042 | lr=0.001000 | train_loss=0.933602 | val_loss=1.101703 | train_metric=9.618108 | val_metric=4.982198
# Epoch 043 | lr=0.001000 | train_loss=1.144024 | val_loss=1.102048 | train_metric=9.616615 | val_metric=4.994141
# Epoch 044 | lr=0.001000 | train_loss=0.872632 | val_loss=1.100254 | train_metric=9.550668 | val_metric=5.005524
# Epoch 045 | lr=0.001000 | train_loss=1.005932 | val_loss=1.098049 | train_metric=9.487861 | val_metric=5.033104
# Epoch 046 | lr=0.001000 | train_loss=0.848722 | val_loss=1.098564 | train_metric=9.476563 | val_metric=5.048000
# Epoch 047 | lr=0.001000 | train_loss=0.886917 | val_loss=1.096402 | train_metric=9.387110 | val_metric=5.078609
# Epoch 048 | lr=0.001000 | train_loss=0.770931 | val_loss=1.096290 | train_metric=9.315833 | val_metric=5.103315
# Epoch 049 | lr=0.001000 | train_loss=0.841450 | val_loss=1.095087 | train_metric=9.294350 | val_metric=5.115164
# Epoch 050 | lr=0.001000 | train_loss=0.857764 | val_loss=1.094313 | train_metric=9.262520 | val_metric=5.131459
# Epoch 051 | lr=0.001000 | train_loss=0.951105 | val_loss=1.094353 | train_metric=9.301040 | val_metric=5.110578
# Epoch 052 | lr=0.001000 | train_loss=0.857753 | val_loss=1.093860 | train_metric=9.287451 | val_metric=5.109377
# Epoch 053 | lr=0.001000 | train_loss=0.881218 | val_loss=1.094762 | train_metric=9.262532 | val_metric=5.122271
# Epoch 054 | lr=0.001000 | train_loss=0.968106 | val_loss=1.094840 | train_metric=9.288678 | val_metric=5.115636
# Epoch 055 | lr=0.001000 | train_loss=0.821169 | val_loss=1.096534 | train_metric=9.273189 | val_metric=5.121989
# Epoch 056 | lr=0.001000 | train_loss=0.842960 | val_loss=1.092725 | train_metric=9.172583 | val_metric=5.168555
# Epoch 057 | lr=0.001000 | train_loss=0.833937 | val_loss=1.095256 | train_metric=9.160114 | val_metric=5.180486
# Epoch 058 | lr=0.001000 | train_loss=0.715114 | val_loss=1.093282 | train_metric=9.170672 | val_metric=5.171762
# Epoch 059 | lr=0.001000 | train_loss=0.953789 | val_loss=1.090612 | train_metric=9.177079 | val_metric=5.179989
# Epoch 060 | lr=0.001000 | train_loss=0.797598 | val_loss=1.089642 | train_metric=9.138894 | val_metric=5.198173
# Epoch 061 | lr=0.001000 | train_loss=0.766811 | val_loss=1.087152 | train_metric=9.127996 | val_metric=5.202812
# Epoch 062 | lr=0.001000 | train_loss=0.806393 | val_loss=1.087335 | train_metric=9.096821 | val_metric=5.191070
# Epoch 063 | lr=0.001000 | train_loss=0.809941 | val_loss=1.088155 | train_metric=9.097926 | val_metric=5.191632
# Epoch 064 | lr=0.001000 | train_loss=1.032217 | val_loss=1.085027 | train_metric=8.924010 | val_metric=5.286985
# Epoch 065 | lr=0.001000 | train_loss=0.717992 | val_loss=1.082476 | train_metric=8.891303 | val_metric=5.305964
# Epoch 066 | lr=0.001000 | train_loss=0.734347 | val_loss=1.083465 | train_metric=8.874384 | val_metric=5.316941
# Epoch 067 | lr=0.001000 | train_loss=0.699376 | val_loss=1.083068 | train_metric=8.848396 | val_metric=5.331217
# Epoch 068 | lr=0.001000 | train_loss=0.987369 | val_loss=1.081326 | train_metric=8.817691 | val_metric=5.357474
# Epoch 069 | lr=0.001000 | train_loss=0.734189 | val_loss=1.082308 | train_metric=8.803210 | val_metric=5.350577
# Epoch 070 | lr=0.001000 | train_loss=0.945417 | val_loss=1.078364 | train_metric=8.810435 | val_metric=5.351295
# Epoch 071 | lr=0.001000 | train_loss=1.141470 | val_loss=1.076423 | train_metric=8.722204 | val_metric=5.403238
# Epoch 072 | lr=0.001000 | train_loss=0.932576 | val_loss=1.076704 | train_metric=8.777765 | val_metric=5.370711
# Epoch 073 | lr=0.001000 | train_loss=0.848916 | val_loss=1.075795 | train_metric=8.777817 | val_metric=5.374915
# Epoch 074 | lr=0.001000 | train_loss=0.750514 | val_loss=1.079682 | train_metric=8.752758 | val_metric=5.379951
# Epoch 075 | lr=0.001000 | train_loss=0.647906 | val_loss=1.078588 | train_metric=8.723268 | val_metric=5.404839
# Epoch 076 | lr=0.001000 | train_loss=0.680481 | val_loss=1.078305 | train_metric=8.603378 | val_metric=5.474333
# Epoch 077 | lr=0.001000 | train_loss=0.997282 | val_loss=1.074213 | train_metric=8.620942 | val_metric=5.474748
# Epoch 078 | lr=0.001000 | train_loss=0.923976 | val_loss=1.074378 | train_metric=8.560308 | val_metric=5.494536
# Epoch 079 | lr=0.001000 | train_loss=0.638707 | val_loss=1.077070 | train_metric=8.585200 | val_metric=5.459634
# Epoch 080 | lr=0.001000 | train_loss=0.927707 | val_loss=1.075240 | train_metric=8.519553 | val_metric=5.495553
# Medium FCNN (gelu):
#   test_loss (scaled MSE) = 0.507919
#   test_MAE = 8.063763
#   test_R2 = -0.438805
# (60000, 1, 28, 28)
# (60000,)
# (8000, 1, 28, 28) (8000, 10)
# (2000, 1, 28, 28) (2000, 10)
# (2000, 1, 28, 28) (2000, 10)
# Epoch 001 | lr=0.000333 | train_loss=2.220406 | val_loss=2.070078 | train_metric=0.470250 | val_metric=0.477500
# Epoch 002 | lr=0.000667 | train_loss=1.454543 | val_loss=0.809868 | train_metric=0.768875 | val_metric=0.778500
# Epoch 003 | lr=0.001000 | train_loss=0.615338 | val_loss=0.444511 | train_metric=0.862750 | val_metric=0.868500
# Epoch 004 | lr=0.001000 | train_loss=0.411356 | val_loss=0.331887 | train_metric=0.894125 | val_metric=0.898500
# Epoch 005 | lr=0.001000 | train_loss=0.335700 | val_loss=0.286987 | train_metric=0.905500 | val_metric=0.904000
# Epoch 006 | lr=0.001000 | train_loss=0.282908 | val_loss=0.236575 | train_metric=0.924750 | val_metric=0.921500
# Epoch 007 | lr=0.001000 | train_loss=0.249858 | val_loss=0.214235 | train_metric=0.932875 | val_metric=0.928500
# Epoch 008 | lr=0.001000 | train_loss=0.221005 | val_loss=0.201875 | train_metric=0.933750 | val_metric=0.935500
# Epoch 009 | lr=0.001000 | train_loss=0.196078 | val_loss=0.182121 | train_metric=0.943625 | val_metric=0.943000
# Epoch 010 | lr=0.001000 | train_loss=0.182154 | val_loss=0.168410 | train_metric=0.948625 | val_metric=0.947500
# Test accuracy: 0.9443
# (6000, 1, 28, 28) (1000, 1, 28, 28) (1000, 1, 28, 28)
# Epoch 001 | lr=0.000500 | train_loss=0.221348 | val_loss=0.196385 | train_metric=0.432491 | val_metric=0.432646
# Epoch 002 | lr=0.001000 | train_loss=0.115024 | val_loss=0.070071 | train_metric=0.142612 | val_metric=0.141472
# Epoch 003 | lr=0.001000 | train_loss=0.074095 | val_loss=0.066588 | train_metric=0.169658 | val_metric=0.168577
# Epoch 004 | lr=0.001000 | train_loss=0.069923 | val_loss=0.065382 | train_metric=0.155390 | val_metric=0.154182
# Epoch 005 | lr=0.001000 | train_loss=0.068527 | val_loss=0.064842 | train_metric=0.153878 | val_metric=0.152610
# Epoch 006 | lr=0.001000 | train_loss=0.067791 | val_loss=0.064520 | train_metric=0.151792 | val_metric=0.150491
# Epoch 007 | lr=0.001000 | train_loss=0.066908 | val_loss=0.064072 | train_metric=0.149280 | val_metric=0.147920
# Epoch 008 | lr=0.001000 | train_loss=0.066197 | val_loss=0.063572 | train_metric=0.147299 | val_metric=0.145880
# Epoch 009 | lr=0.001000 | train_loss=0.065358 | val_loss=0.062827 | train_metric=0.144643 | val_metric=0.143353
# Epoch 010 | lr=0.001000 | train_loss=0.064177 | val_loss=0.061570 | train_metric=0.140500 | val_metric=0.139677
# Epoch 011 | lr=0.001000 | train_loss=0.062789 | val_loss=0.060491 | train_metric=0.136849 | val_metric=0.136368
# Epoch 012 | lr=0.001000 | train_loss=0.061689 | val_loss=0.059642 | train_metric=0.135675 | val_metric=0.135446
# Epoch 013 | lr=0.001000 | train_loss=0.060633 | val_loss=0.058375 | train_metric=0.133907 | val_metric=0.133840
# Epoch 014 | lr=0.001000 | train_loss=0.059197 | val_loss=0.056522 | train_metric=0.127922 | val_metric=0.127893
# Epoch 015 | lr=0.001000 | train_loss=0.057593 | val_loss=0.055045 | train_metric=0.124814 | val_metric=0.124584
# Autoencoder test loss (MSE): 0.0550096356436775
# Autoencoder test MAE: 0.12465861387715316

# %%
import torch
from torch.autograd import Variable
import numpy
import unittest

# %%
class TestLayers(unittest.TestCase):
    def test_Linear(self):
        np.random.seed(42)
        torch.manual_seed(42)

        batch_size, n_in, n_out = 2, 3, 4
        for _ in range(100):
            # layers initialization
            torch_layer = torch.nn.Linear(n_in, n_out)
            custom_layer = Linear(n_in, n_out)
            custom_layer.W = torch_layer.weight.data.numpy()
            custom_layer.b = torch_layer.bias.data.numpy()

            layer_input = np.random.uniform(-10, 10, (batch_size, n_in)).astype(np.float32)
            next_layer_grad = np.random.uniform(-10, 10, (batch_size, n_out)).astype(np.float32)

            # 1. check layer output
            custom_layer_output = custom_layer.updateOutput(layer_input)
            layer_input_var = Variable(torch.from_numpy(layer_input), requires_grad=True)
            torch_layer_output_var = torch_layer(layer_input_var)
            self.assertTrue(np.allclose(torch_layer_output_var.data.numpy(), custom_layer_output, atol=1e-6))

            # 2. check layer input grad
            custom_layer_grad = custom_layer.updateGradInput(layer_input, next_layer_grad)
            torch_layer_output_var.backward(torch.from_numpy(next_layer_grad))
            torch_layer_grad_var = layer_input_var.grad
            self.assertTrue(np.allclose(torch_layer_grad_var.data.numpy(), custom_layer_grad, atol=1e-6))

            # 3. check layer parameters grad
            custom_layer.accGradParameters(layer_input, next_layer_grad)
            weight_grad = custom_layer.gradW
            bias_grad = custom_layer.gradb
            torch_weight_grad = torch_layer.weight.grad.data.numpy()
            torch_bias_grad = torch_layer.bias.grad.data.numpy()
            self.assertTrue(np.allclose(torch_weight_grad, weight_grad, atol=1e-6))
            self.assertTrue(np.allclose(torch_bias_grad, bias_grad, atol=1e-6))

    def test_SoftMax(self):
        np.random.seed(42)
        torch.manual_seed(42)

        batch_size, n_in = 2, 4
        for _ in range(100):
            # layers initialization
            torch_layer = torch.nn.Softmax(dim=1)
            custom_layer = SoftMax()

            layer_input = np.random.uniform(-10, 10, (batch_size, n_in)).astype(np.float32)
            next_layer_grad = np.random.random((batch_size, n_in)).astype(np.float32)
            next_layer_grad /= next_layer_grad.sum(axis=-1, keepdims=True)
            next_layer_grad = next_layer_grad.clip(1e-5,1.)
            next_layer_grad = 1. / next_layer_grad

            # 1. check layer output
            custom_layer_output = custom_layer.updateOutput(layer_input)
            layer_input_var = Variable(torch.from_numpy(layer_input), requires_grad=True)
            torch_layer_output_var = torch_layer(layer_input_var)
            self.assertTrue(np.allclose(torch_layer_output_var.data.numpy(), custom_layer_output, atol=1e-5))

            # 2. check layer input grad
            custom_layer_grad = custom_layer.updateGradInput(layer_input, next_layer_grad)
            torch_layer_output_var.backward(torch.from_numpy(next_layer_grad))
            torch_layer_grad_var = layer_input_var.grad
            self.assertTrue(np.allclose(torch_layer_grad_var.data.numpy(), custom_layer_grad, atol=1e-5))

    def test_LogSoftMax(self):
        np.random.seed(42)
        torch.manual_seed(42)

        batch_size, n_in = 2, 4
        for _ in range(100):
            # layers initialization
            torch_layer = torch.nn.LogSoftmax(dim=1)
            custom_layer = LogSoftMax()

            layer_input = np.random.uniform(-10, 10, (batch_size, n_in)).astype(np.float32)
            next_layer_grad = np.random.random((batch_size, n_in)).astype(np.float32)
            next_layer_grad /= next_layer_grad.sum(axis=-1, keepdims=True)

            # 1. check layer output
            custom_layer_output = custom_layer.updateOutput(layer_input)
            layer_input_var = Variable(torch.from_numpy(layer_input), requires_grad=True)
            torch_layer_output_var = torch_layer(layer_input_var)
            self.assertTrue(np.allclose(torch_layer_output_var.data.numpy(), custom_layer_output, atol=1e-6))

            # 2. check layer input grad
            custom_layer_grad = custom_layer.updateGradInput(layer_input, next_layer_grad)
            torch_layer_output_var.backward(torch.from_numpy(next_layer_grad))
            torch_layer_grad_var = layer_input_var.grad
            self.assertTrue(np.allclose(torch_layer_grad_var.data.numpy(), custom_layer_grad, atol=1e-6))

    def test_BatchNormalization(self):
        np.random.seed(42)
        torch.manual_seed(42)

        batch_size, n_in = 32, 16
        for _ in range(100):
            # layers initialization
            slope = np.random.uniform(0.01, 0.05)
            alpha = 0.9
            custom_layer = BatchNormalization(alpha)
            custom_layer.train()
            torch_layer = torch.nn.BatchNorm1d(n_in, eps=custom_layer.EPS, momentum=1.-alpha, affine=False)
            custom_layer.moving_mean = torch_layer.running_mean.numpy().copy()
            custom_layer.moving_variance = torch_layer.running_var.numpy().copy()

            layer_input = np.random.uniform(-5, 5, (batch_size, n_in)).astype(np.float32)
            next_layer_grad = np.random.uniform(-5, 5, (batch_size, n_in)).astype(np.float32)

            # 1. check layer output
            custom_layer_output = custom_layer.updateOutput(layer_input)
            layer_input_var = Variable(torch.from_numpy(layer_input), requires_grad=True)
            torch_layer_output_var = torch_layer(layer_input_var)
            self.assertTrue(np.allclose(torch_layer_output_var.data.numpy(), custom_layer_output, atol=1e-6))

            # 2. check layer input grad
            custom_layer_grad = custom_layer.updateGradInput(layer_input, next_layer_grad)
            torch_layer_output_var.backward(torch.from_numpy(next_layer_grad))
            torch_layer_grad_var = layer_input_var.grad
            self.assertTrue(np.allclose(torch_layer_grad_var.data.numpy(), custom_layer_grad, atol=1e-5))

            # 3. check moving mean
            self.assertTrue(np.allclose(custom_layer.moving_mean, torch_layer.running_mean.numpy()))
            # we don't check moving_variance because pytorch uses slightly different formula for it:
            # it computes moving average for unbiased variance (i.e var*N/(N-1))
            #self.assertTrue(np.allclose(custom_layer.moving_variance, torch_layer.running_var.numpy()))

            # 4. check evaluation mode
            custom_layer.moving_variance = torch_layer.running_var.numpy().copy()
            custom_layer.evaluate()
            custom_layer_output = custom_layer.updateOutput(layer_input)
            torch_layer.eval()
            torch_layer_output_var = torch_layer(layer_input_var)
            self.assertTrue(np.allclose(torch_layer_output_var.data.numpy(), custom_layer_output, atol=1e-6))

    def test_Sequential(self):
        np.random.seed(42)
        torch.manual_seed(42)

        batch_size, n_in = 2, 4
        for _ in range(100):
            # layers initialization
            alpha = 0.9
            torch_layer = torch.nn.BatchNorm1d(n_in, eps=BatchNormalization.EPS, momentum=1.-alpha, affine=True)
            torch_layer.bias.data = torch.from_numpy(np.random.random(n_in).astype(np.float32))
            custom_layer = Sequential()
            bn_layer = BatchNormalization(alpha)
            bn_layer.moving_mean = torch_layer.running_mean.numpy().copy()
            bn_layer.moving_variance = torch_layer.running_var.numpy().copy()
            custom_layer.add(bn_layer)
            scaling_layer = ChannelwiseScaling(n_in)
            scaling_layer.gamma = torch_layer.weight.data.numpy()
            scaling_layer.beta = torch_layer.bias.data.numpy()
            custom_layer.add(scaling_layer)
            custom_layer.train()

            layer_input = np.random.uniform(-5, 5, (batch_size, n_in)).astype(np.float32)
            next_layer_grad = np.random.uniform(-5, 5, (batch_size, n_in)).astype(np.float32)

            # 1. check layer output
            custom_layer_output = custom_layer.updateOutput(layer_input)
            layer_input_var = Variable(torch.from_numpy(layer_input), requires_grad=True)
            torch_layer_output_var = torch_layer(layer_input_var)
            self.assertTrue(np.allclose(torch_layer_output_var.data.numpy(), custom_layer_output, atol=1e-5))

            # 2. check layer input grad
            custom_layer_grad = custom_layer.backward(layer_input, next_layer_grad)
            torch_layer_output_var.backward(torch.from_numpy(next_layer_grad))
            torch_layer_grad_var = layer_input_var.grad
            self.assertTrue(np.allclose(torch_layer_grad_var.data.numpy(), custom_layer_grad, atol=1e-5))

            # 3. check layer parameters grad
            weight_grad, bias_grad = custom_layer.getGradParameters()[1]
            torch_weight_grad = torch_layer.weight.grad.data.numpy()
            torch_bias_grad = torch_layer.bias.grad.data.numpy()
            self.assertTrue(np.allclose(torch_weight_grad, weight_grad, atol=1e-6))
            self.assertTrue(np.allclose(torch_bias_grad, bias_grad, atol=1e-6))

    def test_Dropout(self):
        np.random.seed(42)

        batch_size, n_in = 2, 4
        for _ in range(100):
            # layers initialization
            p = np.random.uniform(0.3, 0.7)
            layer = Dropout(p)
            layer.train()

            layer_input = np.random.uniform(-5, 5, (batch_size, n_in)).astype(np.float32)
            next_layer_grad = np.random.uniform(-5, 5, (batch_size, n_in)).astype(np.float32)

            # 1. check layer output
            layer_output = layer.updateOutput(layer_input)
            self.assertTrue(np.all(np.logical_or(np.isclose(layer_output, 0),
                                        np.isclose(layer_output*(1.-p), layer_input))))

            # 2. check layer input grad
            layer_grad = layer.updateGradInput(layer_input, next_layer_grad)
            self.assertTrue(np.all(np.logical_or(np.isclose(layer_grad, 0),
                                        np.isclose(layer_grad*(1.-p), next_layer_grad))))

            # 3. check evaluation mode
            layer.evaluate()
            layer_output = layer.updateOutput(layer_input)
            self.assertTrue(np.allclose(layer_output, layer_input))

            # 4. check mask
            p = 0.0
            layer = Dropout(p)
            layer.train()
            layer_output = layer.updateOutput(layer_input)
            self.assertTrue(np.allclose(layer_output, layer_input))

            p = 0.5
            layer = Dropout(p)
            layer.train()
            layer_input = np.random.uniform(5, 10, (batch_size, n_in)).astype(np.float32)
            next_layer_grad = np.random.uniform(5, 10, (batch_size, n_in)).astype(np.float32)
            layer_output = layer.updateOutput(layer_input)
            zeroed_elem_mask = np.isclose(layer_output, 0)
            layer_grad = layer.updateGradInput(layer_input, next_layer_grad)
            self.assertTrue(np.all(zeroed_elem_mask == np.isclose(layer_grad, 0)))

            # 5. dropout mask should be generated independently for every input matrix element, not for row/column
            batch_size, n_in = 1000, 1
            p = 0.8
            layer = Dropout(p)
            layer.train()

            layer_input = np.random.uniform(5, 10, (batch_size, n_in)).astype(np.float32)
            layer_output = layer.updateOutput(layer_input)
            self.assertTrue(np.sum(np.isclose(layer_output, 0)) != layer_input.size)

            layer_input = layer_input.T
            layer_output = layer.updateOutput(layer_input)
            self.assertTrue(np.sum(np.isclose(layer_output, 0)) != layer_input.size)

    def test_Conv2d(self):
        hyperparams = [
            {'batch_size': 8, 'in_channels': 3, 'out_channels': 6, 'height': 32, 'width': 32,
             'kernel_size': 3, 'stride': 1, 'padding': 1, 'bias': True, 'padding_mode': 'zeros'},
            {'batch_size': 4, 'in_channels': 1, 'out_channels': 2, 'height': 28, 'width': 28,
             'kernel_size': 5, 'stride': 2, 'padding': 2, 'bias': False, 'padding_mode': 'replicate'},
            {'batch_size': 16, 'in_channels': 3, 'out_channels': 3, 'height': 64, 'width': 64,
             'kernel_size': 3, 'stride': 2, 'padding': 'same', 'bias': True, 'padding_mode': 'reflect'},
            {'batch_size': 2, 'in_channels': 3, 'out_channels': 8, 'height': 10, 'width': 10,
             'kernel_size': 2, 'stride': (1,2), 'padding': 0, 'bias': True, 'padding_mode': 'zeros'},
        ]
        np.random.seed(42)
        torch.manual_seed(42)

        for _ in range(100):
          for params in hyperparams:
              with self.subTest(params=params):

                  batch_size = params['batch_size']
                  in_channels = params['in_channels']
                  out_channels = params['out_channels']
                  height = params['height']
                  width = params['width']
                  kernel_size = params['kernel_size']
                  stride = params['stride']
                  padding = params['padding']
                  bias = params['bias']
                  padding_mode = params['padding_mode']

                  custom_layer = Conv2d(in_channels, out_channels, kernel_size,
                                        stride=stride, padding=padding, bias=bias,
                                        padding_mode=padding_mode)
                  custom_layer.train()


                  if padding == 'same':
                    if isinstance(stride, tuple):
                        if stride != (1, 1):
                            continue
                    else:
                        if stride != 1:
                            continue

                
                  torch_layer = torch.nn.Conv2d(in_channels, out_channels, kernel_size,
                                                stride=stride, padding=padding, bias=bias,
                                                padding_mode=padding_mode)

                  custom_layer.weight = torch_layer.weight.detach().numpy().copy()
                  if bias:
                      custom_layer.bias = torch_layer.bias.detach().numpy().copy()

                  layer_input = np.random.randn(batch_size, in_channels, height, width).astype(np.float32)
                  input_var = torch.tensor(layer_input, requires_grad=True)

                  custom_output = custom_layer.updateOutput(layer_input)
                  torch_output = torch_layer(input_var)
                  self.assertTrue(
                      np.allclose(torch_output.detach().numpy(), custom_output, atol=1e-6))

                  next_layer_grad = np.random.randn(*torch_output.shape).astype(np.float32)
                  custom_grad = custom_layer.updateGradInput(layer_input, next_layer_grad)
                  torch_output.backward(torch.tensor(next_layer_grad))
                  torch_grad = input_var.grad.detach().numpy()
                  self.assertTrue(
                      np.allclose(torch_grad, custom_grad, atol=1e-5))


    def test_LeakyReLU(self):
        np.random.seed(42)
        torch.manual_seed(42)

        batch_size, n_in = 2, 4
        for _ in range(100):
            # layers initialization
            slope = np.random.uniform(0.01, 0.05)
            torch_layer = torch.nn.LeakyReLU(slope)
            custom_layer = LeakyReLU(slope)

            layer_input = np.random.uniform(-5, 5, (batch_size, n_in)).astype(np.float32)
            next_layer_grad = np.random.uniform(-5, 5, (batch_size, n_in)).astype(np.float32)

            # 1. check layer output
            custom_layer_output = custom_layer.updateOutput(layer_input)
            layer_input_var = Variable(torch.from_numpy(layer_input), requires_grad=True)
            torch_layer_output_var = torch_layer(layer_input_var)
            self.assertTrue(np.allclose(torch_layer_output_var.data.numpy(), custom_layer_output, atol=1e-6))

            # 2. check layer input grad
            custom_layer_grad = custom_layer.updateGradInput(layer_input, next_layer_grad)
            torch_layer_output_var.backward(torch.from_numpy(next_layer_grad))
            torch_layer_grad_var = layer_input_var.grad
            self.assertTrue(np.allclose(torch_layer_grad_var.data.numpy(), custom_layer_grad, atol=1e-6))

    def test_ELU(self):
        np.random.seed(42)
        torch.manual_seed(42)

        batch_size, n_in = 2, 4
        for _ in range(100):
            # layers initialization
            alpha = 1.0
            torch_layer = torch.nn.ELU(alpha)
            custom_layer = ELU(alpha)

            layer_input = np.random.uniform(-5, 5, (batch_size, n_in)).astype(np.float32)
            next_layer_grad = np.random.uniform(-5, 5, (batch_size, n_in)).astype(np.float32)

            # 1. check layer output
            custom_layer_output = custom_layer.updateOutput(layer_input)
            layer_input_var = Variable(torch.from_numpy(layer_input), requires_grad=True)
            torch_layer_output_var = torch_layer(layer_input_var)
            self.assertTrue(np.allclose(torch_layer_output_var.data.numpy(), custom_layer_output, atol=1e-6))

            # 2. check layer input grad
            custom_layer_grad = custom_layer.updateGradInput(layer_input, next_layer_grad)
            torch_layer_output_var.backward(torch.from_numpy(next_layer_grad))
            torch_layer_grad_var = layer_input_var.grad
            self.assertTrue(np.allclose(torch_layer_grad_var.data.numpy(), custom_layer_grad, atol=1e-6))

    def test_SoftPlus(self):
        np.random.seed(42)
        torch.manual_seed(42)

        batch_size, n_in = 2, 4
        for _ in range(100):
            # layers initialization
            torch_layer = torch.nn.Softplus()
            custom_layer = SoftPlus()

            layer_input = np.random.uniform(-5, 5, (batch_size, n_in)).astype(np.float32)
            next_layer_grad = np.random.uniform(-5, 5, (batch_size, n_in)).astype(np.float32)

            # 1. check layer output
            custom_layer_output = custom_layer.updateOutput(layer_input)
            layer_input_var = Variable(torch.from_numpy(layer_input), requires_grad=True)
            torch_layer_output_var = torch_layer(layer_input_var)
            self.assertTrue(np.allclose(torch_layer_output_var.data.numpy(), custom_layer_output, atol=1e-6))

            # 2. check layer input grad
            custom_layer_grad = custom_layer.updateGradInput(layer_input, next_layer_grad)
            torch_layer_output_var.backward(torch.from_numpy(next_layer_grad))
            torch_layer_grad_var = layer_input_var.grad
            self.assertTrue(np.allclose(torch_layer_grad_var.data.numpy(), custom_layer_grad, atol=1e-6))

    def test_ClassNLLCriterionUnstable(self):
        np.random.seed(42)
        torch.manual_seed(42)

        batch_size, n_in = 2, 4
        for _ in range(100):
            # layers initialization
            torch_layer = torch.nn.NLLLoss()
            custom_layer = ClassNLLCriterionUnstable()

            layer_input = np.random.uniform(0, 1, (batch_size, n_in)).astype(np.float32)
            layer_input /= layer_input.sum(axis=-1, keepdims=True)
            layer_input = layer_input.clip(custom_layer.EPS, 1. - custom_layer.EPS)  # unifies input
            target_labels = np.random.choice(n_in, batch_size).astype(np.int64)
            target = np.zeros((batch_size, n_in), np.float32)
            target[np.arange(batch_size), target_labels] = 1  # one-hot encoding

            # 1. check layer output
            custom_layer_output = custom_layer.updateOutput(layer_input, target)
            layer_input_var = Variable(torch.from_numpy(layer_input), requires_grad=True)
            torch_layer_output_var = torch_layer(torch.log(layer_input_var),
                                                 Variable(torch.from_numpy(target_labels), requires_grad=False))
            self.assertTrue(np.allclose(torch_layer_output_var.data.numpy(), custom_layer_output, atol=1e-6))

            # 2. check layer input grad
            custom_layer_grad = custom_layer.updateGradInput(layer_input, target)
            torch_layer_output_var.backward()
            torch_layer_grad_var = layer_input_var.grad
            self.assertTrue(np.allclose(torch_layer_grad_var.data.numpy(), custom_layer_grad, atol=1e-6))

    def test_ClassNLLCriterion(self):
        np.random.seed(42)
        torch.manual_seed(42)

        batch_size, n_in = 2, 4
        for _ in range(100):
            # layers initialization
            torch_layer = torch.nn.NLLLoss()
            custom_layer = ClassNLLCriterion()

            layer_input = np.random.uniform(-5, 5, (batch_size, n_in)).astype(np.float32)
            layer_input = torch.nn.LogSoftmax(dim=1)(Variable(torch.from_numpy(layer_input))).data.numpy()
            target_labels = np.random.choice(n_in, batch_size).astype(np.int64)
            target = np.zeros((batch_size, n_in), np.float32)
            target[np.arange(batch_size), target_labels] = 1  # one-hot encoding

            # 1. check layer output
            custom_layer_output = custom_layer.updateOutput(layer_input, target)
            layer_input_var = Variable(torch.from_numpy(layer_input), requires_grad=True)
            torch_layer_output_var = torch_layer(layer_input_var,
                                                 Variable(torch.from_numpy(target_labels), requires_grad=False))
            self.assertTrue(np.allclose(torch_layer_output_var.data.numpy(), custom_layer_output, atol=1e-6))

            # 2. check layer input grad
            custom_layer_grad = custom_layer.updateGradInput(layer_input, target)
            torch_layer_output_var.backward()
            torch_layer_grad_var = layer_input_var.grad
            self.assertTrue(np.allclose(torch_layer_grad_var.data.numpy(), custom_layer_grad, atol=1e-6))


    def test_MaxPool2d(self):
        np.random.seed(42)
        torch.manual_seed(42)

        batch_size, channels, height, width = 4, 3, 16, 16
        kernel_size, stride, padding = 2, 2, 0

        for _ in range(100):
          custom_module = MaxPool2d(kernel_size, stride, padding)
          custom_module.train()

          torch_module = torch.nn.MaxPool2d(kernel_size, stride=stride, padding=padding)

          input_np = np.random.randn(batch_size, channels, height, width).astype(np.float32)
          input_var = torch.tensor(input_np, requires_grad=True)

          custom_output = custom_module.updateOutput(input_np)
          torch_output = torch_module(input_var)
          self.assertTrue(
              np.allclose(torch_output.detach().numpy(), custom_output, atol=1e-6))

          next_grad = np.random.randn(*torch_output.shape).astype(np.float32)
          custom_grad = custom_module.updateGradInput(input_np, next_grad)
          torch_output.backward(torch.tensor(next_grad))
          torch_grad = input_var.grad.detach().numpy()
          self.assertTrue(
              np.allclose(torch_grad, custom_grad, atol=1e-5))

    def test_AvgPool2d(self):
        np.random.seed(42)
        torch.manual_seed(42)

        batch_size, channels, height, width = 4, 3, 16, 16
        kernel_size, stride, padding = 3, 2, 1

        for _ in range(100):
          custom_module = AvgPool2d(kernel_size, stride, padding)
          custom_module.train()

          torch_module = torch.nn.AvgPool2d(kernel_size, stride=stride, padding=padding)

          input_np = np.random.randn(batch_size, channels, height, width).astype(np.float32)
          input_var = torch.tensor(input_np, requires_grad=True)

          custom_output = custom_module.updateOutput(input_np)
          torch_output = torch_module(input_var)
          self.assertTrue(
              np.allclose(torch_output.detach().numpy(), custom_output, atol=1e-6))

          next_grad = np.random.randn(*torch_output.shape).astype(np.float32)
          custom_grad = custom_module.updateGradInput(input_np, next_grad)
          torch_output.backward(torch.tensor(next_grad))
          torch_grad = input_var.grad.detach().numpy()
          self.assertTrue(
              np.allclose(torch_grad, custom_grad, atol=1e-5))

    def test_Flatten(self):
        np.random.seed(42)
        torch.manual_seed(42)

        test_params = [
            {'start_dim': 1, 'end_dim': -1},
            {'start_dim': 2, 'end_dim': 3},
            {'start_dim': 0, 'end_dim': -1},
        ]

        for _ in range(100):
          for params in test_params:
              with self.subTest(params=params):
                  start_dim = params['start_dim']
                  end_dim = params['end_dim']

                  custom_module = Flatten(start_dim, end_dim)
                  input_np = np.random.randn(2, 3, 4, 5).astype(np.float32)
                  input_var = torch.tensor(input_np, requires_grad=True)

                  custom_output = custom_module.updateOutput(input_np)
                  torch_output = torch.flatten(input_var, start_dim=start_dim, end_dim=end_dim)
                  self.assertTrue(
                      np.allclose(torch_output.detach().numpy(), custom_output, atol=1e-6))

                  next_grad = np.random.randn(*torch_output.shape).astype(np.float32)
                  custom_grad = custom_module.updateGradInput(input_np, next_grad)
                  torch_output.backward(torch.tensor(next_grad))
                  torch_grad = input_var.grad.detach().numpy()
                  self.assertTrue(
                      np.allclose(torch_grad, custom_grad, atol=1e-6))

    def test_Gelu(self):
        np.random.seed(42)
        torch.manual_seed(42)

        for _ in range(100):
          custom_module = Gelu()
          custom_module.train()

          torch_module = torch.nn.GELU()

          input_np = np.random.randn(10, 5).astype(np.float32)
          input_var = torch.tensor(input_np, requires_grad=True)

          custom_output = custom_module.updateOutput(input_np)
          torch_output = torch_module(input_var)
          self.assertTrue(
              np.allclose(torch_output.detach().numpy(), custom_output, atol=1e-6))

          next_grad = np.random.randn(*torch_output.shape).astype(np.float32)
          custom_grad = custom_module.updateGradInput(input_np, next_grad)
          torch_output.backward(torch.tensor(next_grad))
          torch_grad = input_var.grad.detach().numpy()
          self.assertTrue(
              np.allclose(torch_grad, custom_grad, atol=1e-5))


suite = unittest.TestLoader().loadTestsFromTestCase(TestLayers)
unittest.TextTestRunner(verbosity=2).run(suite)
# Out:
# test_AvgPool2d (__main__.TestLayers.test_AvgPool2d) ... ok
# test_BatchNormalization (__main__.TestLayers.test_BatchNormalization) ... ok
# test_ClassNLLCriterion (__main__.TestLayers.test_ClassNLLCriterion) ... ok
# test_ClassNLLCriterionUnstable (__main__.TestLayers.test_ClassNLLCriterionUnstable) ... ok
# test_Conv2d (__main__.TestLayers.test_Conv2d) ... ok
# test_Dropout (__main__.TestLayers.test_Dropout) ... ok
# test_ELU (__main__.TestLayers.test_ELU) ... ok
# test_Flatten (__main__.TestLayers.test_Flatten) ... ok
# test_Gelu (__main__.TestLayers.test_Gelu) ... ok
# test_LeakyReLU (__main__.TestLayers.test_LeakyReLU) ... ok
# test_Linear (__main__.TestLayers.test_Linear) ... ok
# test_LogSoftMax (__main__.TestLayers.test_LogSoftMax) ... ok
# test_MaxPool2d (__main__.TestLayers.test_MaxPool2d) ... ok
# test_Sequential (__main__.TestLayers.test_Sequential) ... ok
# test_SoftMax (__main__.TestLayers.test_SoftMax) ... ok
# test_SoftPlus (__main__.TestLayers.test_SoftPlus) ... ok
#
# ----------------------------------------------------------------------
# Ran 16 tests in 10.451s
#
# OK
# <unittest.runner.TextTestResult run=16 errors=0 failures=0>

# %%
suite = unittest.TestSuite()
suite.addTest(TestLayers('test_Sequential'))
unittest.TextTestRunner(verbosity=2).run(suite)
# Out:
# test_Sequential (__main__.TestLayers.test_Sequential) ... ok
#
# ----------------------------------------------------------------------
# Ran 1 test in 0.158s
#
# OK
# <unittest.runner.TextTestResult run=1 errors=0 failures=0>

# %% [markdown]
# # Комментарии
#
# Для Conv2d в тесте было padding='same' при stride != 1 через torch.nn.Conv2d, а локальная версия PyTorch это не поддерживает
#
#
# Для Sequential был конфуз: расхождение было на уровне численной погрешности в float32, поэтому допуск сравнения я ослабил с 1e-6 до 1у-5
